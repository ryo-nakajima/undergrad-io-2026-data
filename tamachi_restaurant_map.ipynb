# %% [markdown]
# # 田町駅周辺 ラーメン・牛丼 分布マップ (2016 vs 2026)
#
# 田町駅・三田駅周辺のラーメン屋と牛丼屋の分布を2016年と2026年で比較する。
#
# ## データソース
# - **2016年**: 食べログ地図検索のスクリーンショット（PDF）から画像処理でピン座標を抽出 + 食べログ閉店ページから住所・座標を復元
# - **2026年**: 食べログから直接スクレイピング（店名・評価・座標）

# %%
# foliumがインストールされていない場合はインストール
import subprocess, sys
try:
    import folium
except ModuleNotFoundError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "folium", "-q"])
    import folium

from folium.plugins import MarkerCluster
import pandas as pd
import json
import math
import os

# %% [markdown]
# ## 1. データ読み込み

# %%
# Google Colab: GitHubから直接データを読み込み
import io, urllib.request

GITHUB_BASE = 'https://raw.githubusercontent.com/ryo-nakajima/undergrad-io-2026-data/main/data'

def read_csv_from_github(filename):
    url = f'{GITHUB_BASE}/{filename}'
    response = urllib.request.urlopen(url)
    return pd.read_csv(io.StringIO(response.read().decode('utf-8')))

# ローカル実行時はdata/から読む（Colab時はGitHubから）
import os
if os.path.exists('data'):
    DATA_DIR = 'data'
    ramen_2016 = pd.read_csv(os.path.join(DATA_DIR, 'ramen_2016.csv'))
    gyudon_2016 = pd.read_csv(os.path.join(DATA_DIR, 'gyudon_2016.csv'))
    ramen_2026 = pd.read_csv(os.path.join(DATA_DIR, 'ramen_2026.csv'))
    gyudon_2026 = pd.read_csv(os.path.join(DATA_DIR, 'gyudon_2026.csv'))
else:
    ramen_2016 = read_csv_from_github('ramen_2016.csv')
    gyudon_2016 = read_csv_from_github('gyudon_2016.csv')
    ramen_2026 = read_csv_from_github('ramen_2026.csv')
    gyudon_2026 = read_csv_from_github('gyudon_2026.csv')

ramen_2026 = ramen_2026.drop_duplicates(subset='name', keep='first')
gyudon_2026 = gyudon_2026.drop_duplicates(subset='name', keep='first')

print(f'2016年: ラーメン {len(ramen_2016)}店, 牛丼 {len(gyudon_2016)}店')
print(f'2026年: ラーメン {len(ramen_2026)}店, 牛丼 {len(gyudon_2026)}店')
# Out:
# 2016年: ラーメン 27店, 牛丼 5店
# 2026年: ラーメン 30店, 牛丼 6店

# %%
# データプレビュー（全件表示）
pd.set_option('display.max_rows', None)

print('=== 2016 ラーメン (全店) ===')
display(ramen_2016[['name','rating_2016','status']].sort_values('status'))

print('\n=== 2016 牛丼 (全店) ===')
display(gyudon_2016[['name','rating_2016','status']])

print('\n=== 2026 ラーメン (全店) ===')
cols_r26 = ['name','rating','since_2016','opened','address']
cols_r26 = [c for c in cols_r26 if c in ramen_2026.columns]
display(ramen_2026[cols_r26].sort_values(['since_2016','opened'], ascending=[True,True]))

print('\n=== 2026 牛丼 (全店) ===')
display(gyudon_2026[['name','rating','address']])
# Out:
# === 2016 ラーメン (全店) ===
#             name  rating_2016  status
# 13         むらさき山         3.55     営業中
# 21   豚骨醤油らーめん 學虎         3.06     営業中
# 20        香家 三田店         3.41     営業中
# 19       壱角家 田町店         3.08     営業中
# 18    三田製麺所 三田本店         3.31     営業中
# 17     博多一瑞亭 三田店         3.54     営業中
# 15      やっとこ 三田店         3.52     営業中
# 14  横浜家系らーめん 武源家         3.55     営業中
# 12   ラーメン二郎 三田本店         3.68     営業中
# 24      北の大地 三田店         3.10      閉店
# 23     麺屋武蔵 芝浦別巻         3.40      閉店
# 22  麻布ラーメン 慶應三田店         3.20      閉店
# 16      麺屋武蔵 芝浦店         3.54      閉店
# 0   ますたにラーメン 田町店         3.50      閉店
# 11  日の出らーめん 田町分店         3.05      閉店
# 10   麺処こぶし 慶應通り店         3.10      閉店
# 9      げんこつ屋 三田店         3.00      閉店
# 8        四天王 田町店         3.00      閉店
# 7         らぁめん 丸         3.10      閉店
# 6       天下一品 田町店         3.05      閉店
# 5        壱角家 三田店         3.05      閉店
# 4        太龍軒 田町店         3.10      閉店
# 3          てるぼうず         3.20      閉店
# 2    太陽のトマト麺 三田店         3.15      閉店
# 1     麻布ラーメン 芝浦店         3.30      閉店
# 26  麻布ラーメン 芝四丁目店         3.29      閉店
# 25            天空         3.10  閉店(移転)
# === 2016 牛丼 (全店) ===
#         name  rating_2016 status
# 0    吉野家 芝浦店         3.01    営業中
# 1     松屋 三田店         3.00    営業中
# 2    なか卯 芝浦店         3.00    営業中
# 3    すき家 三田店         3.00    営業中
# 4  すき家 芝四丁目店         3.00    営業中
# === 2026 ラーメン (全店) ===
#                   name  rating since_2016       opened  \
# 0                むらさき山    3.66         存続          NaN
# 1            博多一瑞亭 三田店    3.54         存続          NaN
# 6              壱角家 田町店    3.08         存続          NaN
# 8         麻布ラーメン 芝四丁目店    3.29         存続          NaN
# 21        横浜家系らーめん 武源家    3.55         存続          NaN
# 22         ラーメン二郎 三田本店    3.77         存続          NaN
# 23            やっとこ 三田店    3.51         存続          NaN
# 29              香家 三田店    3.43         存続          NaN
# 10           日高屋 田町西口店    3.08         新規   2014年5月27日
# 19            舎鈴 田町駅前店    3.25         新規    2016年8月7日
# 17            広州市場 田町店    3.49         新規  2018年11月15日
# 2            日高屋 田町東口店    3.05         新規   2018年5月17日
# 20          えっちゃんラーメン。    3.62         新規   2020年10月8日
# 7                玉 田町店    3.44         新規    2020年9月1日
# 11              らぁ麺 六花    3.53         新規   2021年3月14日
# 13             貝そば もぉむ    3.56         新規   2022年8月20日
# 27        田中そば店 田町タワー店    3.49         新規   2023年10月2日
# 9        つけ麺屋 やすべえ 田町店    3.12         新規   2024年7月23日
# 14  MISO HANAMICHI 三田店    3.40         新規  2025年12月10日
# 26                 大総家    3.52         新規   2025年1月11日
# 25         寿限無 担々麺 三田店    3.36         新規   2025年3月13日
# 24      らぁ麺 はやし田 田町芝浦店    3.06         新規   2025年7月10日
# 12             伍福軒 田町店    3.31         新規   2025年7月15日
# 5              麺屋武蔵 道貫    3.06         新規   2025年7月27日
# 3              品川家 三田店    3.29         新規          NaN
# 4                  楽喜亭    3.27         新規          NaN
# 15              威風 三田店    3.13         新規          NaN
# 16                 斬鉄軒    3.26         新規          NaN
# 18                もとまる    3.49         新規          NaN
# 28           君子麻婆麺 三田店     NaN         新規          NaN
#
#                                     address
# 0                              東京都港区芝5-23-8
# 1                   東京都港区芝5-14-1マック三田コート102
# 6                        東京都港区芝浦3-7-15チトセビル
# 8                              東京都港区芝4-5-15
# 21                      東京都港区三田3-1-2北村ビル 1F
# 22                            東京都港区三田2-16-4
# 23                             東京都港区三田3-1-1
# 29                            東京都港区三田2-14-9
# 10            東京都港区芝5-31-15センチュリー三田ビル 1F・2F
# 19                 東京都港区芝5-34-7田町センタービル 106
# 17       東京都港区芝浦3-1-21田町ステーションタワーS（ムスブ田町）1F
# 2                       東京都港区芝浦3-1なぎさテラス 2F
# 20                   東京都港区芝浦3-1-30なぎさテラス 1F
# 7   東京都港区芝浦3-1-1msb Tamachi 田町ステーションタワーN 1F
# 11                      東京都港区芝5-29-5山田ビル 1F
# 13                  東京都港区芝浦4-2-22東京ベイビュウ 1F
# 27                     東京都港区芝5-33-11田町タワー2F
# 9                      東京都港区芝5-33-11田町タワー2F
# 14                     東京都港区三田3-1-13石田ビル 1F
# 26                            東京都港区芝5-24-12
# 25                      東京都港区三田3-3-4橋本ビル 1F
# 24                   東京都港区芝浦3-12-18バウパレス 1F
# 12                            東京都港区芝5-17-11
# 5                   東京都港区芝5-14-14ビジデンス三慶 1F
# 3                              東京都港区芝5-31-3
# 4                            東京都港区芝3-42-71F
# 15                            東京都港区芝5-26-10
# 16                            東京都港区芝浦2-12-5
# 18                東京都港区芝5-31-7三田ステーションビル 1F
# 28                 東京都港区三田3-4-10リーラヒジリザカ 1F
# === 2026 牛丼 (全店) ===
#          name  rating        address
# 0     すき家 三田店    3.07   東京都港区芝5-25-9
# 1  吉野家 田町駅芝浦店    3.06  東京都港区芝浦3-15-7
# 2   すき家 芝四丁目店    3.05    東京都港区芝4-7-1
# 3  すき家 芝浦四丁目店    3.03  東京都港区芝浦4-9-18
# 4      松屋 三田店    3.06   東京都港区芝5-22-3
# 5     なか卯 芝浦店    3.04  東京都港区芝浦3-13-3

# %% [markdown]
# ## 2. 田町駅から800m圏のフィルタリング

# %%
# 田町駅の座標
TAMACHI_LAT = 35.64564
TAMACHI_LNG = 139.74753
RADIUS_M = 800

def haversine(lat1, lng1, lat2, lng2):
    """2点間の距離(m)を計算"""
    R = 6371000
    dlat = math.radians(lat2 - lat1)
    dlng = math.radians(lng2 - lng1)
    a = math.sin(dlat/2)**2 + math.cos(math.radians(lat1))*math.cos(math.radians(lat2))*math.sin(dlng/2)**2
    return R * 2 * math.asin(math.sqrt(a))

def filter_by_radius(df, lat_col='lat', lng_col='lng', radius=RADIUS_M):
    """田町駅からradius(m)以内の店舗のみ"""
    df = df.dropna(subset=[lat_col, lng_col]).copy()
    df['dist_m'] = df.apply(lambda r: haversine(TAMACHI_LAT, TAMACHI_LNG, r[lat_col], r[lng_col]), axis=1)
    return df[df['dist_m'] <= radius].copy()

# フィルタリング
r16 = filter_by_radius(ramen_2016)
g16 = filter_by_radius(gyudon_2016)
r26 = filter_by_radius(ramen_2026)
g26 = filter_by_radius(gyudon_2026)

print(f'田町駅から{RADIUS_M}m以内:')
print(f'  2016 ラーメン: {len(r16)}店 / 牛丼: {len(g16)}店')
print(f'  2026 ラーメン: {len(r26)}店 / 牛丼: {len(g26)}店')
# Out:
# 田町駅から800m以内:
#   2016 ラーメン: 27店 / 牛丼: 5店
#   2026 ラーメン: 30店 / 牛丼: 6店

# %% [markdown]
# ## 3. インタラクティブ比較マップ
#
# レイヤー切り替えで以下を表示/非表示にできます:
# - ラーメン 2016年（オレンジ）
# - ラーメン 2026年（赤）
# - 牛丼 2016年（青）
# - 牛丼 2026年（緑）

# %%
from IPython.display import display, HTML

def create_comparison_map(r16, r26, g16, g26):
    """2016 vs 2026 インタラクティブ比較マップ"""
    m = folium.Map(
        location=[TAMACHI_LAT, TAMACHI_LNG],
        zoom_start=15,
        tiles='https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png',
        attr='&copy; <a href="https://carto.com/">CARTO</a> &copy; <a href="https://www.openstreetmap.org/copyright">OSM</a>'
    )

    # 800m圏の円
    folium.Circle(
        [TAMACHI_LAT, TAMACHI_LNG],
        radius=RADIUS_M,
        color='gray', fill=False, weight=2,
        popup=f'田町駅から{RADIUS_M}m'
    ).add_to(m)

    # 駅マーカー
    stations = folium.FeatureGroup(name='駅', show=True)
    folium.Marker(
        [35.64564, 139.74753], popup='<b>JR田町駅</b>',
        icon=folium.Icon(color='darkblue', icon='info-sign')
    ).add_to(stations)
    folium.Marker(
        [35.64806, 139.74164], popup='<b>三田駅（都営）</b>',
        icon=folium.Icon(color='darkgreen', icon='info-sign')
    ).add_to(stations)
    stations.add_to(m)

    # --- ラーメン 2016 ---
    fg_r16 = folium.FeatureGroup(name='ラーメン 2016年', show=True)
    for _, row in r16.iterrows():
        popup_html = f"<b>{row['name']}</b><br>評価: {row.get('rating_2016','?')}<br>状態: {row.get('status','')}"
        folium.CircleMarker(
            [row['lat'], row['lng']], radius=7,
            popup=popup_html, tooltip=row['name'],
            color='#FF6600', fill=True, fillColor='#FF6600', fillOpacity=0.7
        ).add_to(fg_r16)
    fg_r16.add_to(m)

    # --- ラーメン 2026 ---
    fg_r26 = folium.FeatureGroup(name='ラーメン 2026年', show=True)
    for _, row in r26.iterrows():
        rating = row.get('rating', '?')
        popup_html = f"<b>{row['name']}</b><br>評価: {rating}<br>住所: {row.get('address','')}"
        folium.CircleMarker(
            [row['lat'], row['lng']], radius=7,
            popup=popup_html, tooltip=row['name'],
            color='#CC0000', fill=True, fillColor='#CC0000', fillOpacity=0.7
        ).add_to(fg_r26)
    fg_r26.add_to(m)

    # --- 牛丼 2016 ---
    fg_g16 = folium.FeatureGroup(name='牛丼 2016年', show=False)
    for _, row in g16.iterrows():
        popup_html = f"<b>{row['name']}</b><br>評価: {row.get('rating_2016','?')}"
        folium.CircleMarker(
            [row['lat'], row['lng']], radius=9,
            popup=popup_html, tooltip=row['name'],
            color='#0066CC', fill=True, fillColor='#0066CC', fillOpacity=0.7
        ).add_to(fg_g16)
    fg_g16.add_to(m)

    # --- 牛丼 2026 ---
    fg_g26 = folium.FeatureGroup(name='牛丼 2026年', show=False)
    for _, row in g26.iterrows():
        rating = row.get('rating', '?')
        popup_html = f"<b>{row['name']}</b><br>評価: {rating}<br>住所: {row.get('address','')}"
        folium.CircleMarker(
            [row['lat'], row['lng']], radius=9,
            popup=popup_html, tooltip=row['name'],
            color='#009933', fill=True, fillColor='#009933', fillOpacity=0.7
        ).add_to(fg_g26)
    fg_g26.add_to(m)

    folium.LayerControl(collapsed=False).add_to(m)
    return m

m = create_comparison_map(r16, r26, g16, g26)

# HTMLファイルとしても保存（ブラウザで直接開ける）
m.save('comparison_map.html')

# 確実にインラインで表示
display(HTML(m._repr_html_()))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e461d6edbaf75b86eceae2543bf7f2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e461d6edbaf75b86eceae2543bf7f2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e461d6edbaf75b86eceae2543bf7f2d = L.map(
#                 &quot;map_3e461d6edbaf75b86eceae2543bf7f2d&quot;,
#                 {
#                     center: [35.64564, 139.74753],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9c0a90f535fd4f50781f2f8f42b4ede = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://carto.com/\&quot;\u003eCARTO\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOSM\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9c0a90f535fd4f50781f2f8f42b4ede.addTo(map_3e461d6edbaf75b86eceae2543bf7f2d);
#
#
#             var circle_9930967cff32feb56995d95bed7bbc3b = L.circle(
#                 [35.64564, 139.74753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 800, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_3e461d6edbaf75b86eceae2543bf7f2d);
#
#
#         var popup_d731dd9417757bec8f6935a22922db1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3963e6a931a94a1ec9834cf2f99de49 = $(`&lt;div id=&quot;html_f3963e6a931a94a1ec9834cf2f99de49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;田町駅から800m&lt;/div&gt;`)[0];
#                 popup_d731dd9417757bec8f6935a22922db1a.setContent(html_f3963e6a931a94a1ec9834cf2f99de49);
#
#
#
#         circle_9930967cff32feb56995d95bed7bbc3b.bindPopup(popup_d731dd9417757bec8f6935a22922db1a)
#         ;
#
#
#
#
#             var feature_group_aa13760b1c2cd7f2210887d46d0006d3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1c5bf64f03b774be0899f94eaab71651 = L.marker(
#                 [35.64564, 139.74753],
#                 {
# }
#             ).addTo(feature_group_aa13760b1c2cd7f2210887d46d0006d3);
#
#
#             var icon_39fdf21cd6d3dfd5ea556339f7a2e1b2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_57a6eb3de44dfcbca39495f95810e8f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_134777be0443666cd317bd8d5a31ea8a = $(`&lt;div id=&quot;html_134777be0443666cd317bd8d5a31ea8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;JR田町駅&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_57a6eb3de44dfcbca39495f95810e8f5.setContent(html_134777be0443666cd317bd8d5a31ea8a);
#
#
#
#         marker_1c5bf64f03b774be0899f94eaab71651.bindPopup(popup_57a6eb3de44dfcbca39495f95810e8f5)
#         ;
#
#
#
#
#                 marker_1c5bf64f03b774be0899f94eaab71651.setIcon(icon_39fdf21cd6d3dfd5ea556339f7a2e1b2);
#
#
#             var marker_9c15c52123c6a9fc597b539a0f050d37 = L.marker(
#                 [35.64806, 139.74164],
#                 {
# }
#             ).addTo(feature_group_aa13760b1c2cd7f2210887d46d0006d3);
#
#
#             var icon_51646f80b4b9dcbbeee2903d03793165 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkgreen&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_859b29f51f1f6d14744e6cd9cc413239 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe06b91234012e79b02ffec827505918 = $(`&lt;div id=&quot;html_fe06b91234012e79b02ffec827505918&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;三田駅（都営）&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_859b29f51f1f6d14744e6cd9cc413239.setContent(html_fe06b91234012e79b02ffec827505918);
#
#
#
#         marker_9c15c52123c6a9fc597b539a0f050d37.bindPopup(popup_859b29f

# %% [markdown]
# ## 4. 統計サマリー

# %%
print('=' * 50)
print('田町駅から800m以内の店舗数比較')
print('=' * 50)
print(f'{"":>20} {"2016年":>8} {"2026年":>8} {"変化":>8}')
print('-' * 50)
print(f'{"ラーメン":>20} {len(r16):>8} {len(r26):>8} {len(r26)-len(r16):>+8}')
print(f'{"牛丼":>20} {len(g16):>8} {len(g26):>8} {len(g26)-len(g16):>+8}')
print('-' * 50)

# ラーメン店の変遷
common_ramen = set(r16['name']) & set(r26['name'])
only_2016_r = set(r16['name']) - set(r26['name'])
only_2026_r = set(r26['name']) - set(r16['name'])

print(f'\nラーメン店の変遷:')
print(f'  両年に存在: {len(common_ramen)}店')
print(f'  2016年のみ: {len(only_2016_r)}店 (閉店等)')
print(f'  2026年のみ: {len(only_2026_r)}店 (新規開店)')
if common_ramen:
    print(f'  存続店: {", ".join(sorted(common_ramen))}')

# 牛丼店の変遷
common_gyudon = set(g16['name']) & set(g26['name'])
only_2016_g = set(g16['name']) - set(g26['name'])
only_2026_g = set(g26['name']) - set(g16['name'])

print(f'\n牛丼店の変遷:')
print(f'  両年に存在: {len(common_gyudon)}店')
print(f'  2016年のみ: {len(only_2016_g)}店 (閉店等)')
print(f'  2026年のみ: {len(only_2026_g)}店 (新規)')
if common_gyudon:
    print(f'  存続店: {", ".join(sorted(common_gyudon))}')
if only_2016_g:
    print(f'  閉店等: {", ".join(sorted(only_2016_g))}')
if only_2026_g:
    print(f'  新規: {", ".join(sorted(only_2026_g))}')
# Out:
# ==================================================
# 田町駅から800m以内の店舗数比較
# ==================================================
#                         2016年    2026年       変化
# --------------------------------------------------
#                 ラーメン       27       30       +3
#                   牛丼        5        6       +1
# --------------------------------------------------
#
# ラーメン店の変遷:
#   両年に存在: 8店
#   2016年のみ: 19店 (閉店等)
#   2026年のみ: 22店 (新規開店)
#   存続店: むらさき山, やっとこ 三田店, ラーメン二郎 三田本店, 博多一瑞亭 三田店, 壱角家 田町店, 横浜家系らーめん 武源家, 香家 三田店, 麻布ラーメン 芝四丁目店
#
# 牛丼店の変遷:
#   両年に存在: 4店
#   2016年のみ: 1店 (閉店等)
#   2026年のみ: 2店 (新規)
#   存続店: すき家 三田店, すき家 芝四丁目店, なか卯 芝浦店, 松屋 三田店
#   閉店等: 吉野家 芝浦店
#   新規: すき家 芝浦四丁目店, 吉野家 田町駅芝浦店

# %% [markdown]
# ## 5. 個別年度マップ

# %%
def create_year_map(ramen_df, gyudon_df, year, rating_col='rating_2016'):
    """単一年度のマップ"""
    m = folium.Map(
        location=[TAMACHI_LAT, TAMACHI_LNG],
        zoom_start=15, tiles='https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png',
        attr='&copy; <a href="https://carto.com/">CARTO</a> &copy; <a href="https://www.openstreetmap.org/copyright">OSM</a>'
    )
    folium.Circle(
        [TAMACHI_LAT, TAMACHI_LNG], radius=RADIUS_M,
        color='gray', fill=False, weight=2
    ).add_to(m)

    # ラーメン
    fg_r = folium.FeatureGroup(name=f'ラーメン ({year})', show=True)
    for _, row in ramen_df.iterrows():
        r = row.get(rating_col, row.get('rating', '?'))
        folium.CircleMarker(
            [row['lat'], row['lng']], radius=8,
            popup=f"<b>{row['name']}</b><br>評価: {r}",
            tooltip=row['name'],
            color='#FF6600', fill=True, fillColor='#FF6600', fillOpacity=0.8
        ).add_to(fg_r)
    fg_r.add_to(m)

    # 牛丼
    fg_g = folium.FeatureGroup(name=f'牛丼 ({year})', show=True)
    for _, row in gyudon_df.iterrows():
        r = row.get(rating_col, row.get('rating', '?'))
        folium.CircleMarker(
            [row['lat'], row['lng']], radius=10,
            popup=f"<b>{row['name']}</b><br>評価: {r}",
            tooltip=row['name'],
            color='#0066CC', fill=True, fillColor='#0066CC', fillOpacity=0.8
        ).add_to(fg_g)
    fg_g.add_to(m)

    folium.LayerControl().add_to(m)
    return m

print('=== 2016年 ===')
m2016 = create_year_map(r16, g16, '2016', 'rating_2016')
m2016.save('map_2016.html')
display(HTML(m2016._repr_html_()))
# Out:
# === 2016年 ===
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d535214eb3676ae5b628853ec4c465b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d535214eb3676ae5b628853ec4c465b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d535214eb3676ae5b628853ec4c465b = L.map(
#                 &quot;map_2d535214eb3676ae5b628853ec4c465b&quot;,
#                 {
#                     center: [35.64564, 139.74753],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e29f628b9ddd9eb8503484a6130f794 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://carto.com/\&quot;\u003eCARTO\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOSM\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e29f628b9ddd9eb8503484a6130f794.addTo(map_2d535214eb3676ae5b628853ec4c465b);
#
#
#             var circle_267ebc3373cfc8ee1f817a036f857ceb = L.circle(
#                 [35.64564, 139.74753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 800, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_2d535214eb3676ae5b628853ec4c465b);
#
#
#             var feature_group_81ddff646285f22c0f21886637e4f3a6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_286a6eb9d3ac6a5496ed14d45fc44d82 = L.circleMarker(
#                 [35.647299, 139.744774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF6600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF6600&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_81ddff646285f22c0f21886637e4f3a6);
#
#
#         var popup_449689e3296d6d91e61f772002398f77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a7523ba9bc548fcdcfded464e2a7305 = $(`&lt;div id=&quot;html_5a7523ba9bc548fcdcfded464e2a7305&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;ますたにラーメン 田町店&lt;/b&gt;&lt;br&gt;評価: 3.5&lt;/div&gt;`)[0];
#                 popup_449689e3296d6d91e61f772002398f77.setContent(html_5a7523ba9bc548fcdcfded464e2a7305);
#
#
#
#         circle_marker_286a6eb9d3ac6a5496ed14d45fc44d82.bindPopup(popup_449689e3296d6d91e61f772002398f77)
#         ;
#
#
#
#
#             circle_marker_286a6eb9d3ac6a5496ed14d45fc44d82.bindTooltip(
#                 `&lt;div&gt;
#                      ますたにラーメン 田町店
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_85f0176ebd7619e180958a5f50c40fc0 = L.circleMarker(
#                 [35.642547, 139.749542],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF6600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF6600&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_81ddff646285f22c0f21886637e4f3a6);
#
#
#         var popup_5a1b04f4b3d994dda56e0b27b5ff343b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea79275034b8809c8a6433b8cb027a04 = $(`&lt;div id=&quot;html_ea79275034b8809c8a6433b8cb027a04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;麻布ラーメン 芝浦店&lt;/b&gt;&lt;br&gt;評価: 3.3&lt;/div&gt;`)[0];
#                 popup_5a1b04f4b3d994dda56e0b27b5ff343b.setContent(html_ea79275034b8809c8a6433b8cb027a04);
#
#
#
#         circle_marker_85f0176ebd7619e180958a5f50c40fc0.bindPopup(popup_5a1b04f4b3d994dda56e0b27b5ff343b)
#         ;
#
#
#
#
#             circle_marker_85f0176ebd7619e180958a5f50c40fc0.bindTooltip(
#                 `&lt;div&gt;
#                      麻布ラーメン 芝浦店

# %%
print('=== 2026年 ===')
m2026 = create_year_map(r26, g26, '2026', 'rating')
m2026.save('map_2026.html')
display(HTML(m2026._repr_html_()))
# Out:
# === 2026年 ===
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c43c0b02eefeee3ce56bdd6250666ff4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c43c0b02eefeee3ce56bdd6250666ff4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c43c0b02eefeee3ce56bdd6250666ff4 = L.map(
#                 &quot;map_c43c0b02eefeee3ce56bdd6250666ff4&quot;,
#                 {
#                     center: [35.64564, 139.74753],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_750ceaf6b9985390383a6fc6e1534d2c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://carto.com/\&quot;\u003eCARTO\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOSM\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_750ceaf6b9985390383a6fc6e1534d2c.addTo(map_c43c0b02eefeee3ce56bdd6250666ff4);
#
#
#             var circle_fc67a8fcfe778dcf3b458dd64fe804ee = L.circle(
#                 [35.64564, 139.74753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 800, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c43c0b02eefeee3ce56bdd6250666ff4);
#
#
#             var feature_group_06a08617d83eef6238bb9c65adea0a05 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_a536fad87b0f06e0f7b1827ab691f453 = L.circleMarker(
#                 [35.64790033792538, 139.74619498290016],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF6600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF6600&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_06a08617d83eef6238bb9c65adea0a05);
#
#
#         var popup_e185f7ae061808bcde0a5c04fea19926 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49f4cdc7eb44d22bac6480d08b03a0e4 = $(`&lt;div id=&quot;html_49f4cdc7eb44d22bac6480d08b03a0e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;むらさき山&lt;/b&gt;&lt;br&gt;評価: 3.66&lt;/div&gt;`)[0];
#                 popup_e185f7ae061808bcde0a5c04fea19926.setContent(html_49f4cdc7eb44d22bac6480d08b03a0e4);
#
#
#
#         circle_marker_a536fad87b0f06e0f7b1827ab691f453.bindPopup(popup_e185f7ae061808bcde0a5c04fea19926)
#         ;
#
#
#
#
#             circle_marker_a536fad87b0f06e0f7b1827ab691f453.bindTooltip(
#                 `&lt;div&gt;
#                      むらさき山
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_5c2b7e4fe199acf6925d8450b0e0b601 = L.circleMarker(
#                 [35.648785637924405, 139.74491408291],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF6600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF6600&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_06a08617d83eef6238bb9c65adea0a05);
#
#
#         var popup_57907264d262370d84e0e1a45bdcff58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_763cf07d75788d0fb2734dc3c40af640 = $(`&lt;div id=&quot;html_763cf07d75788d0fb2734dc3c40af640&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;博多一瑞亭 三田店&lt;/b&gt;&lt;br&gt;評価: 3.54&lt;/div&gt;`)[0];
#                 popup_57907264d262370d84e0e1a45bdcff58.setContent(html_763cf07d75788d0fb2734dc3c40af640);
#
#
#
#         circle_marker_5c2b7e4fe199acf6925d8450b0e0b601.bindPopup(popup_57907264d262370d84e0e1a45bdcff58)
#         ;
#
#
#
#
#             circle_marker_5c2b7e4fe199acf6925d8450b0e0b601.bindTooltip(
#                 `&lt;div&gt;
#                      博多

# %% [markdown]
# ## 技術メモ
#
# ### 2016年データの座標抽出パイプライン
# 1. PDFから地図画像を切り出し（`pdf2image`）
# 2. OpenCVでHSV色空間によるオレンジピン検出
# 3. 輪郭検出 + 形状フィルタ（面積・コンパクト度）
# 4. 4参照点（三田駅・田町駅西口・JR田町・三田通り交差前）でアフィン変換
# 5. 座標精度: RMS ≈ 15m
# 6. 食べログ閉店ページから住所・座標を補完
#
# ### 2026年データ
# - 食べログ一覧ページからスクレイピング
# - 各店舗詳細ページのHTML内に`lat`, `lng`が直接記載
# - `requests` + `BeautifulSoup`で取得
